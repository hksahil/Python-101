# %% [markdown]
# ### Windows Command Line 101

# %%
# !dir
# Out:
#  Volume in drive C is SSD
#  Volume Serial Number is 86EA-9B98
#
#  Directory of C:\Users\Sahil Choudhary\Book\Python
#
# 20-03-2022  01.02 PM    <DIR>          .
# 20-03-2022  01.02 PM    <DIR>          ..
# 29-01-2022  02.55 AM            12,619 .bash_history
# 20-03-2022  01.41 AM    <DIR>          .ipynb_checkpoints
# 19-03-2022  01.24 PM               900 Any() vs All()-Copy1.ipynb
# 19-03-2022  10.12 AM             3,813 Any() vs All().ipynb
# 12-03-2022  03.47 PM             4,263 Applying functions on dataframe.ipynb
# 24-02-2022  11.40 PM             3,188 Array Destructuring.ipynb
# 20-03-2022  12.57 AM            10,433 Automating Excel.ipynb
# 27-02-2022  04.15 AM             2,428 bkpp.txt
# 03-03-2022  08.48 AM               846 BOOLEAN 101 TITLE.ipynb
# 02-03-2022  09.38 PM             1,474 Break and Continue.ipynb
# 20-02-2022  11.39 PM             1,369 Changing data type-Lists.ipynb
# 20-03-2022  01.15 AM             4,400 Changing Datatypes.ipynb
# 12-03-2022  04.26 PM             5,888 Changing the index of Dataframe.ipynb
# 24-02-2022  04.52 PM             2,353 Checking bools.ipynb
# 13-03-2022  03.39 AM             6,797 Checking datatypes.ipynb
# 06-03-2022  11.17 PM           845,560 coding.gif
# 13-03-2022  05.58 PM            20,120 Columns cleaning.ipynb
# 20-03-2022  01.18 AM            21,024 Columns Manipulation.ipynb
# 20-03-2022  01.14 AM            29,578 Converting Data Types - Advance.ipynb
# 26-02-2022  01.28 AM             5,551 Counter Library.ipynb
# 12-03-2022  12.25 PM             4,401 Creating a series.ipynb
# 12-03-2022  01.00 PM            19,428 Creating Dataframes.ipynb
# 20-03-2022  12.58 AM             9,439 CSV.ipynb
# 27-02-2022  05.12 AM               717 DATA TYPES 101 TITLE.ipynb
# 21-02-2022  01.07 AM             1,176 Data Types Nans.ipynb
# 12-03-2022  12.27 PM               850 Dataframe 101 TITLE.ipynb
# 12-03-2022  01.05 PM             1,315 Dataframe Inspection.ipynb
# 13-03-2022  06.37 PM             3,515 Date.ipynb
# 13-03-2022  07.36 PM               863 DateTime 101 TITLE.ipynb
# 13-03-2022  07.21 PM             9,918 DateTime in Pandas.ipynb
# 13-03-2022  06.42 PM             2,870 DateTime.ipynb
# 02-03-2022  09.52 PM               709 Debugging 101.ipynb
# 27-02-2022  05.17 AM               712 DEBUGGING TITLE.ipynb
# 12-03-2022  04.13 PM             7,950 Deleting Columns.ipynb
# 29-01-2022  03.35 AM               246 demo.csv
# 20-03-2022  12.50 PM                20 demo.txt
# 20-03-2022  01.02 PM               254 demo2.csv
# 20-02-2022  06.38 PM             3,123 Dictionaries Comprehension-Filtering.ipynb
# 20-02-2022  11.12 PM             2,194 Dictionaries Comprehension.ipynb
# 20-02-2022  11.36 PM             6,822 Dictionaries.ipynb
# 27-02-2022  05.15 AM               717 DICTIONARY 101 TITLE.ipynb
# 02-03-2022  09.39 PM            10,095 Dictionary advance concepts.ipynb
# 20-02-2022  11.11 PM             2,009 Dictionary Creation.ipynb
# 02-03-2022  10.10 PM             4,157 Enumerate.ipynb
# 16-03-2022  10.47 PM             1,990 Enviroment Variables.ipynb
# 14-03-2022  12.59 AM             4,338 Examples.ipynb
# 27-02-2022  05.14 AM               737 EXCEPTIONAL HANDLING 101 TITLE.ipynb
# 17-03-2022  02.05 AM             2,955 Exceptional Handling.ipynb
# 06-03-2022  11.22 PM           323,184 ezgif.com-gif-maker (1).gif
# 06-03-2022  11.21 PM         1,622,049 ezgif.com-gif-maker.gif
# 20-03-2022  01.50 AM             3,710 Faster python.ipynb
# 17-03-2022  02.09 AM             2,289 File paths.ipynb
# 20-03-2022  01.32 AM             6,655 Filtering with Pandas compared with SQL.ipynb
# 12-03-2022  04.26 PM             7,419 Finding n largest in Dataframe.ipynb
# 13-03-2022  11.55 PM             4,220 Formatting Strings-Copy1.ipynb
# 13-03-2022  11.55 PM             4,220 Formatting Strings.ipynb
# 25-02-2022  02.01 AM            10,452 Function Defination.ipynb
# 02-03-2022  10.05 PM             2,036 Importing Packages.ipynb
# 13-03-2022  11.48 PM            14,959 Indexes.ipynb
# 17-03-2022  12.29 AM             2,207 Install vs Import.ipynb
# 02-03-2022  09.59 PM             1,594 Installing Packages.ipynb
# 13-03-2022  09.31 AM             3,846 Integer Sequence using Range.ipynb
# 12-03-2022  05.27 PM               576 intro.md
# 20-03-2022  01.43 AM             1,826 Jupyter Notebook Basics.ipynb
# 13-03-2022  10.53 PM             2,724 Lambda Functions.ipynb
# 29-01-2022  01.58 AM             8,272 Linux Commands.ipynb
# 27-02-2022  05.16 AM               705 LIST 101 TITLE.ipynb
# 21-02-2022  01.09 AM             2,425 List Add.ipynb
# 02-03-2022  10.03 PM             8,191 List of files in OS.ipynb
# 20-02-2022  06.27 PM             1,279 List to Dictionary.ipynb
# 20-02-2022  06.48 PM             5,222 Lists Creation.ipynb
# 02-03-2022  10.16 PM             2,645 Lists Delete.ipynb
# 20-02-2022  04.51 PM             6,676 Lists Indexes and Slicing-Copy1.ipynb
# 21-02-2022  12.43 AM             8,704 Lists Indexes and Slicing.ipynb
# 02-03-2022  10.18 PM             1,132 Lists Joining.ipynb
# 02-03-2022  10.18 PM             3,946 Lists Read.ipynb
# 02-03-2022  10.17 PM             2,716 Lists Remove Duplicates.ipynb
# 02-03-2022  10.17 PM             1,719 Lists Reversing.ipynb
# 06-03-2022  10.10 PM             4,849 Lists Sorting.ipynb
# 03-03-2022  08.48 AM             1,918 Lists Update.ipynb
# 05-03-2022  01.21 PM             3,706 Lists use cases.ipynb
# 28-01-2022  11.47 PM             9,854 logo.png
# 21-02-2022  12.57 AM            21,977 logo1.PNG
# 27-02-2022  05.13 AM               711 LOOPING 101 TITLE.ipynb
# 16-03-2022  09.53 AM             2,288 Making your own Packages.ipynb
# 12-03-2022  04.27 PM            14,304 Manipulating and Filtering Dataframe.ipynb
# 17-03-2022  02.10 AM             2,625 Manipulating Series.ipynb
# 13-03-2022  11.54 PM             2,131 Markdown 101.ipynb
# 28-01-2022  11.47 PM             3,705 markdown.md
# 25-02-2022  01.19 AM               987 Math Functions.ipynb
# 27-02-2022  05.12 AM               751 MODULES VS PACKAGES VS LIBRARIES TITLE.ipynb
# 19-03-2022  11.44 PM             1,506 Modules vs Packages vs Libraries.ipynb
# 25-02-2022  02.08 AM             1,927 Mutable vs Immutable.ipynb
# 28-01-2022  11.47 PM             3,378 notebooks.ipynb
# 20-03-2022  01.21 AM               850 OS Module Title.ipynb
# 20-03-2022  01.22 AM             5,644 OS Module.ipynb
# 06-03-2022  11.19 PM         1,622,755 ow6u2T.gif
# 12-03-2022  10.53 PM             1,323 Pandas.ipynb
# 20-03-2022  01.04 AM            14,498 Pathlib.ipynb
# 17-03-2022  02.13 AM             2,455 Playing with Date and Time.ipynb
# 18-03-2022  01.59 PM             4,401 Playing with missing values.ipynb
# 07-03-2022  01.54 AM           141,332 Python Concurrency.ipynb
# 27-02-2022  05.14 AM               724 PYTHON MISC CONCEPTS TITLE.ipynb
# 13-03-2022  10.41 PM             4,784 Random module.ipynb
# 19-03-2022  09.54 AM            26,550 re Module.ipynb
# 28-01-2022  11.47 PM             5,524 references.bib
# 13-03-2022  11.58 PM               842 Regex Title.ipynb
# 20-03-2022  01.22 AM             2,883 Regex.ipynb
# 20-02-2022  11.38 PM             1,695 Removing falses from List.ipynb
# 12-03-2022  01.49 PM             6,250 Renaming Columns.ipynb
# 28-01-2022  11.47 PM                30 requirements.txt
# 27-02-2022  05.17 AM               702 RESOURCES TITLE.ipynb
# 20-03-2022  01.58 AM             1,286 Resources.ipynb
# 17-03-2022  02.02 AM                18 sahil.txt
# 12-03-2022  12.23 PM               844 Series 101 TITLE.ipynb
# 20-03-2022  01.28 AM             4,229 Shallow vs Deep Copy.ipynb
# 19-03-2022  01.38 PM            34,363 Slicing Dataframe.ipynb
# 12-03-2022  04.26 PM             8,709 Sorting in Dataframe.ipynb
# 27-02-2022  05.20 AM               709 STRING 101 TITLE.ipynb
# 19-03-2022  10.55 PM             3,867 String Functions.ipynb
# 24-02-2022  11.49 PM             3,708 String.ipynb
# 02-03-2022  10.11 PM           822,177 Tertiary Operator.ipynb
# 17-03-2022  02.12 AM             2,188 Time.ipynb
# 13-03-2022  07.20 PM             1,916 TimeDelta.ipynb
# 02-03-2022  09.41 PM             3,175 Timing your code.ipynb
# 29-01-2022  04.09 AM               743 Untitled.ipynb
# 20-02-2022  04.25 PM                72 Untitled1.ipynb
# 20-02-2022  04.31 PM                72 Untitled2.ipynb
# 24-02-2022  04.50 PM               576 Untitled3.ipynb
# 24-02-2022  11.31 PM               576 Untitled4.ipynb
# 18-02-2022  04.07 PM               576 Untitled5.ipynb
# 07-03-2022  11.15 PM             1,198 Untitled6.ipynb
# 12-03-2022  12.28 PM                72 Untitled7.ipynb
# 16-03-2022  11.03 PM             1,154 Untitled8.ipynb
# 27-02-2022  03.36 AM             1,007 Variable Destructuring.ipynb
# 15-03-2022  07.56 AM             6,686 Web Scraping.ipynb
# 02-03-2022  10.03 PM             1,433 Windows Command Line.ipynb
# 27-02-2022  05.11 AM               717 WINDOWS OS 101 TITLE.ipynb
# 20-03-2022  12.58 AM               863 Working with Files.ipynb
# 16-03-2022  12.58 AM             5,447 Working with text files.ipynb
# 20-03-2022  01.29 AM             6,457 Writting SQL within Pandas.ipynb
# 21-02-2022  01.06 AM             4,936 Zip.ipynb
# 20-03-2022  01.02 PM    <DIR>          _build
# 20-03-2022  12.48 PM             1,602 _config.yml
# 20-03-2022  01.41 AM             4,794 _toc.yml
#              143 File(s)      5,999,751 bytes
#                4 Dir(s)  19,292,700,672 bytes free

# %% [markdown]
# #### Note:In CLI, foldersare called directories
# - Give list of all files and folders in current directory: ```dir```
#     - Files are tagged as Blanks
#     - Folders are tagged as ```<DIR>```
# - Create Folder: ```mkdir <name of folder>```
# - Delete folder: ```rmdir <name of folder>```
#     - Use ```rmdir /s <name of directory>``` if  folder has stuff in it
# - Going one level up in Directory: ```cd <name>```
#     - Going to any folder: ```cd C:\Desktop\Folder\Subfolder```
# - Going one level down in Directory: ```cd ..```
# - Clear Screen: ```cls```
# - Open Files: Type name of file without any command
#     - It opens file in default program

# %% [markdown]
# ### Installing packages

# %% [markdown]
# To install latest version(default) : ```!pip <commands> [options] [name of library] ```
#
# To install previous/specific version: ```!pip <commands> [options] [name of library]==Syntax Number```

# %% [markdown]
# - Commands:
#    - install
#    - uninstall
#    - freeze - Gives a list of all the modules installed with their version in one go in Module name==module version format
# - Options:
#     - ```-h or --help``` to get help
#     - ```pip -h``` Overall help
#     - ```pip subcommand -h``` gives you help for that sub command
#     - ```-y``` automatically says yes to prompts
#     - ```-V``` To know current version
#     - ```-U``` To upgrade package to the latest versions
#     - ```--force-reinstall ``` Reinstall all packages
